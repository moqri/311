# %%
import pandas as pd
import collections
import matplotlib.pyplot as plt
from __future__ import division

# %%
# %matplotlib inline

# %%
def dist(data,service_type):
    df=pd.read_csv(data)
    dg=df[service_type].groupby(df[service_type]).count()
    dist=dg.sort_values(ascending=False)
    return dist,df

# %%
data='../data/boston/311__Service_Requests.csv'
service_type='CASE_TITLE'
dist_df,df=dist(data,service_type)
l1=dist_df[0:50].index
#.plot(kind='bar',figsize=(15,5))
print dist_df.values.sum()
print dist_df[0:50].values.sum()/dist_df.values.sum()
# Out:
# 1027469
# 0.788939617643

# %%
data='../data/cincinnati/Cincinnati_311__Non-Emergency__Service_Requests.csv'
service_type='SERVICE_NAME'
dist_df,df=dist(data,service_type)
l2=dist_df[0:50].index
#.plot(kind='bar',figsize=(15,5))
print dist_df.values.sum()
print dist_df[0:50].values.sum()/dist_df.values.sum()
# Out:
# 555811
# 0.849761879488

# %%
data='../data/los_angeles/MyLA311_Service_Request_Data_2017.csv'
service_type='RequestType'
dist_df,df=dist(data,service_type)
l3=dist_df[0:50].index
#.plot(kind='bar',figsize=(15,5))
print dist_df.values.sum()
print dist_df[0:50].values.sum()/dist_df.values.sum()
# Out:
# 955815
# 1.0

# %%
data='../data/louisvile/citizen311data_2016_0.csv'
service_type='service_name'
dist_df,df=dist(data,service_type)
l4=dist_df[0:50].index
#.plot(kind='bar',figsize=(15,5))
print dist_df.values.sum()
print dist_df[0:50].values.sum()/dist_df.values.sum()
# Out:
# 102039
# 0.887788002626

# %%
data='../data/kansas/311_Call_Center_Service_Requests.csv'
service_type='CATEGORY'
dist_df,df=dist(data,service_type)
l5=dist_df[0:50].index
#.plot(kind='bar',figsize=(15,5))
print dist_df.values.sum()
print dist_df[0:50].values.sum()/dist_df.values.sum()
# Out:
# 1110841
# 0.987161078858

# %%
data='../data/new_orleans/311_Calls__2012-Present_.csv'
service_type='issue_type'
dist_df,df=dist(data,service_type)
l6=dist_df[0:50].index
#.plot(kind='bar',figsize=(15,5))
print dist_df.values.sum()
print dist_df[0:50].values.sum()/dist_df.values.sum()
# Out:
# 244338
# 1.0

# %%
data='../data/nyc/nyc17.csv'
service_type='Complaint Type'
dist_df,df=dist(data,service_type)
l7=dist_df[0:50].index
#.plot(kind='bar',figsize=(15,5))
print dist_df[0:50].values.sum()/dist_df.values.sum()
# Out:
# 0.901279157261

# %%
data='../data/philadelphia/public_cases_fc.csv'
service_type='service_name'
dist_df,df=dist(data,service_type)
l8=dist_df[0:50].index
#.plot(kind='bar',figsize=(15,5))
print dist_df.values.sum()
print dist_df[0:50].values.sum()/dist_df.values.sum()
# Out:
# 1659364
# 0.999957212522

# %%
data='../data/pittsburgh/40776043-ad00-40f5-9dc8-1fde865ff571.csv'
service_type='REQUEST_TYPE'
dist_df,df=dist(data,service_type)
l9=dist_df[0:50].index
#.plot(kind='bar',figsize=(15,5))
print dist_df.values.sum()
print dist_df[0:50].values.sum()/dist_df.values.sum()
# Out:
# 185136
# 0.797964739435

# %%
data='../data/san_diego/get_it_done_311_requests_datasd.csv'
service_type='service_name'
dist_df,df=dist(data,service_type)
l9=dist_df[0:50].index
#.plot(kind='bar',figsize=(15,5))
print dist_df.values.sum()
print dist_df[0:50].values.sum()/dist_df.values.sum()
# Out:
# 161763
# 1.0

# %%
pd.DataFrame([l1,l2,l3,l4,l5,l6,l7,l8,l9]).transpose()
# Out:
#                                           0                                 1  \
# 0               Schedule a Bulk Item Pickup  "Metal Furniture, Spec Collectn"
# 1              Requests for Street Cleaning  "Tall grass/weeds, private prop"
# 2                  Request for Snow Plowing   "Trash, request for collection"
# 3                       Parking Enforcement                 "Pothole, repair"
# 4                Request for Pothole Repair           "Building, residential"
# 5                 Pothole Repair (Internal)        "Litter, private property"
# 6                      Street Light Outages                  "Yard waste,rtc"
# 7               Sidewalk Repair (Make Safe)       "Tires, Special Collection"
# 8                 Schedule Bulk Item Pickup               "Graffiti, removal"
# 9                 Tree Maintenance Requests                     "Dead animal"
# 10                              Sign Repair         "Trash, improper set out"
# 11         Unsatisfactory Living Conditions  "Building, concentratd code enf"
# 12               Request for Recycling Cart   "Recycling, new 96 gallon cart"
# 13                         Graffiti Removal        "Trash cart, registration"
# 14                       Abandoned Vehicles       "Slippery streets, request"
# 15                      Pick up Dead Animal      "Trash cart, swap 95 gallon"
# 16                          Rodent Activity             "Sign, down/missing "
# 17                            CE Collection      "Building, fire escape insp"
# 18      Improper Storage of Trash (Barrels)  "Signal, traf/ped/school repair"
# 19              Building Inspection Request  "Default, police (and junk veh)"
# 20                          Sticker Request  "Building, vacant and open res "
# 21                    Traffic Signal Repair       "Trash cart, new 65 gallon"
# 22                Traffic Signal Inspection       "Trash, tagged collections"
# 23                      Unshoveled Sidewalk          "Annual - c annual insp"
# 24                        New Tree Requests                 "Street cleaning"
# 25                   Animal Generic Request     "Mold, building or apartment"
# 26                      Empty Litter Basket   "Recycling, request to collect"
# 27                         Tree Emergencies   "Dumping, prv prop <2500 sq ft"
# 28                          Sidewalk Repair   "Recycling, new 64 gallon cart"
# 29              Poor Conditions of Property   "Building, vacant and open res"
# 30                         Other: Complaint        "Special collections, rtc"
# 31           Heat - Excessive  Insufficient                   "Light, repair"
# 32                             PWD Graffiti  "Vehicle, abandon priv p access"
# 33  New Sign  Crosswalk or Pavement Marking   "Tall grass/weeds, PS property"
# 34                        Work w/out Permit         "Corner can, overflowing"
# 35              Unsafe/Dangerous Conditions        "Service complaint, trash"
# 36                    Recycling Cart Return          "Recycling, remove cart"
# 37                         Equipment Repair     "Restaurant consult, new lic"
# 38                      Highway Maintenance   "Trash cart, missing 65 gallon"
# 39                               Electrical  "Light loader, infested collctn"
# 40                  Front Desk Interactions  "Tree, dead on priv prop stndrd"
# 41                             Missing Sign         "Sign, street sign faded"
# 42                                  PRINTED     "Roaches - bldg or apartment"
# 43                 General Lighting Request                   "Default, City"
# 44                           Other: Comment    "Unsanitary living conditions"
# 45                    Contractor Complaints  "Yard waste, tagged collections"
# 46                             Space Savers            "Sidewalk, repair haz"
# 47                            Needle Pickup       "Trash cart, new 95 gallon"
# 48                   PublicWorks: Complaint      "Trash cart, swap 35 gallon"
# 49                Missed Trash: District 07     "Parking, grass front yd res"
#
#                              2                 3  \
# 0                  Bulky Items  HIGH GRASS WEEDS
# 1             Graffiti Removal  DAMAGE GARB CART
# 2   Metal/Household Appliances    TRASH PVT PROP
# 3       Illegal Dumping Pickup     EXTERIOR VIOL
# 4             Electronic Waste    STREET POTHOLE
# 5          Homeless Encampment    GARBAGE MISSED
# 6          Dead Animal Removal   ABANDON VEHICLE
# 7                        Other       DEAD ANIMAL
# 8     Single Streetlight Issue     MISCELLANEOUS
# 9   Multiple Streetlight Issue      RECYCLE BINS
# 10          Report Water Waste  STOLEN GARB CART
# 11                    Feedback  VEHICLE PVT PROP
# 12                        None   ILLEGAL DUMPING
# 13                        None     INTERIOR VIOL
# 14                        None   LIGHTING REPAIR
# 15                        None   VAP STRUC WEEDS
# 16                        None    SIGNAGE REPAIR
# 17                        None  TRAF SIGNAL REPR
# 18                        None  NEW RECYCLE CART
# 19                        None   YARD WASTE MISS
# 20                        None        OVERGROWTH
# 21                        None   TRAFFIC CONCERN
# 22                        None  RECYCLING MISSED
# 23                        None    JUNK VIOLATION
# 24                        None     STREET HAZARD
# 25                        None     PARK MAINTAIN
# 26                        None   ZONING CONCERNS
# 27                        None         MOSQUITOS
# 28                        None   SIDEWALK REPAIR
# 29                        None   TRAF SIG TIMING
# 30                        None     VAP LOT WEEDS
# 31                        None       JUNK MISSED
# 32                        None      VAP EXTERIOR
# 33                        None     STREET REPAIR
# 34                        None        NJUNK WEEK
# 35                        None  GARBAGE VIOLATIO
# 36                        None  STOP SIGN REPAIR
# 37                        None       STREET TREE
# 38                        None       SIGNAGE NEW
# 39                        None  NEW GARBAGE CART
# 40                        None   REPORT LITTERER
# 41                        None       RAT BAITING
# 42                        None  GRAFFITI PVTPROP
# 43                        None   ROADSIDE LITTER
# 44                        None    LITTER BASKETS
# 45                        None  SIDEWALK OBSTRUC
# 46                        None  STREET RESURFACE
# 47                        None    SMOKE DETECTOR
# 48                        None             PESTS
# 49                        None          GRAFFITI
#
#                                       4  \
# 0                                 Trash
# 1                   Property Violations
# 2                                Animal
# 3                            Water Leak
# 4                     Trash / Recycling
# 5                                 Trees
# 6                   Nuisance Violations
# 7                        Animals / Pets
# 8   Property / Buildings / Construction
# 9                     Bulky Appointment
# 10                         Public Works
# 11       Property & Nuisance Violations
# 12                           Snow & Ice
# 13                         Street Light
# 14                                Sewer
# 15                              Vehicle
# 16                                Water
# 17                       Mowing / Weeds
# 18          Streets / Roadways / Alleys
# 19                  Storm Water / Sewer
# 20                          Storm Water
# 21                              Pothole
# 22                                Weeds
# 23                   Vehicles / Parking
# 24                          Street Sign
# 25                          Maintenance
# 26                     Lights / Signals
# 27                               Signal
# 28                                Signs
# 29                       Water Services
# 30                        Traffic Study
# 31                        Water Quality
# 32                               Health
# 33                         Traffic Sign
# 34                                 Park
# 35                             Sidewalk
# 36                               Zoning
# 37            Sidewalks / Curbs / Ditch
# 38                        Public Health
# 39                   Parks & Recreation
# 40                             Graffiti
# 41                         Right of Way
# 42                                Ditch
# 43                 City Managers Office
# 44                               Permit
# 45                      Food Protection
# 46                     Downtown Parking
# 47                     Capital Projects
# 48                               Street
# 49                             Cleaning
#
#                                          5                                  6  \
# 0                      Information Request                Noise - Residential
# 1    Maintenance Residential or Commercial                     HEAT/HOT WATER
# 2   Rubbish/Recyclable Material Collection                    Illegal Parking
# 3                          Illegal Dumping                   Blocked Driveway
# 4                        Abandoned Vehicle                   Street Condition
# 5                     Directory Assistance             Street Light Condition
# 6                         Graffiti Removal               UNSANITARY CONDITION
# 7                            Street Defect            Noise - Street/Sidewalk
# 8                      Street Light Outage                       Water System
# 9                      Vacant Lot Clean-Up                              Noise
# 10              Vacant House or Commercial                      PAINT/PLASTER
# 11                                 Salting                           PLUMBING
# 12         Sanitation / Dumpster Violation                 Noise - Commercial
# 13                            Street Trees           Traffic Signal Condition
# 14                Traffic Signal Emergency                              Sewer
# 15                      Building Dangerous             DOF Literature Request
